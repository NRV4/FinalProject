# %%
import pandas as pd
Location = "C:/Users/OWNER/Documents/DataBootcamp/loan/loan.csv"
df = pd.read_csv(Location)
df.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# ...

# %%
df2 = df[['id', 'int_rate', 'term', 'grade', 'sub_grade', 'loan_status', 'emp_length', 'funded_amnt', 'purpose', 'annual_inc']]
df2.head(20)
# Out:
#          id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0   1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1   1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2   1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3   1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 4   1075358     12.69   60 months     B        B5      Current     1 year
# 5   1075269      7.90   36 months     A        A4   Fully Paid    3 years
# 6   1069639     15.96   60 months     C        C5      Current    8 years
# 7   1072053     18.64   36 months     E        E1   Fully Paid    9 years
# 8   1071795     21.28   60 months     F        F2  Charged Off    4 years
# 9   1071570     12.69   60 months     B        B5  Charged Off   < 1 year
# 10  1070078     14.65   60 months     C        C3   Fully Paid    5 years
# 11  1069908     12.69   36 months     B        B5   Fully Paid  10+ years
# ...

# %%
df2nm = df2.dropna()
df2nm.head()
# Out:
#         id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0  1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1  1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2  1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3  1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 4  1075358     12.69   60 months     B        B5      Current     1 year
#
#    funded_amnt         purpose  annual_inc
# 0       5000.0     credit_card     24000.0
# 1       2500.0             car     30000.0
# 2       2400.0  small_business     12252.0
# 3      10000.0           other     49200.0
# 4       3000.0           other     80000.0

# %%
df2.describe()
# Out:
#                  id       int_rate    funded_amnt    annual_inc
# count  8.873790e+05  887379.000000  887379.000000  8.873750e+05
# mean   3.246513e+07      13.246740   14741.877625  7.502759e+04
# std    2.282734e+07       4.381867    8429.897657  6.469830e+04
# min    5.473400e+04       5.320000     500.000000  0.000000e+00
# 25%    9.206643e+06       9.990000    8000.000000  4.500000e+04
# 50%    3.443327e+07      12.990000   13000.000000  6.500000e+04
# 75%    5.490814e+07      16.200000   20000.000000  9.000000e+04
# max    6.861706e+07      28.990000   35000.000000  9.500000e+06

# %%
df2nm.describe()
# Out:
#                  id       int_rate    funded_amnt    annual_inc
# count  8.425500e+05  842550.000000  842550.000000  8.425500e+05
# mean   3.229207e+07      13.245163   14899.890748  7.635332e+04
# std    2.283984e+07       4.385807    8444.846052  6.564285e+04
# min    5.473400e+04       5.320000     500.000000  1.896000e+03
# 25%    9.045242e+06       9.990000    8325.000000  4.700000e+04
# 50%    3.431207e+07      12.990000   13200.000000  6.500000e+04
# 75%    5.452376e+07      16.200000   20000.000000  9.000000e+04
# max    6.861706e+07      28.990000   35000.000000  9.500000e+06

# %%
pd.value_counts(df2nm['loan_status'])
# Out:
# Current                                                568686
# Fully Paid                                             200351
# Charged Off                                             42723
# Late (31-120 days)                                      10872
# Issued                                                   7829
# In Grace Period                                          6015
# Late (16-30 days)                                        2215
# Does not meet the credit policy. Status:Fully Paid       1965
# Default                                                  1148
# Does not meet the credit policy. Status:Charged Off       746
# Name: loan_status, dtype: int64

# %%
pd.value_counts(df2nm['grade'])
# Out:
# B    241804
# C    233184
# A    141246
# D    131774
# E     67263
# F     22004
# G      5275
# Name: grade, dtype: int64

# %%
pd.value_counts(df2nm['emp_length'])
# Out:
# 10+ years    291569
# 2 years       78870
# < 1 year      70601
# 3 years       70026
# 1 year        57095
# 5 years       55704
# 4 years       52529
# 7 years       44594
# 8 years       43955
# 6 years       42950
# 9 years       34657
# Name: emp_length, dtype: int64

# %%
def score_emp(x):
    if x== '< 1 year':
        return 0
    if x=='1 year':
        return 1
    if x == '2 years':
        return 2
    if x == '3 years':
        return 3
    if x=='4 years':
        return 4
    if x=='5 years':
        return 5
    if x == '6 years':
        return 6
    if x == '7 years':
        return 7
    if x == '8 years':
        return 8
    if x == '9 years':
        return 9
    if x == '10+ years':
        return 10

# %%
df2nm['emp_length2'] = df2nm['emp_length'].apply(score_emp)
df2nm.tail(10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               id  int_rate        term grade sub_grade loan_status emp_length  \
# 887368  36250208     14.99   60 months     C        C5     Current    8 years
# 887369  36421485      8.67   36 months     B        B1  Fully Paid  10+ years
# 887370  35094480      9.49   36 months     B        B2     Current    8 years
# 887372  36330911     11.99   36 months     B        B5     Current   < 1 year
# 887373  36221446     15.59   36 months     D        D1     Current  10+ years
# ...

# %%
pd.value_counts(df2nm['emp_length2'])
# Out:
# 10    291569
# 2      78870
# 0      70601
# 3      70026
# 1      57095
# 5      55704
# 4      52529
# 7      44594
# 8      43955
# 6      42950
# 9      34657
# Name: emp_length2, dtype: int64

# %%
pd.value_counts(df2nm['purpose'])
# Out:
# debt_consolidation    499744
# credit_card           194981
# home_improvement       48499
# other                  40113
# major_purchase         16384
# small_business         10109
# car                     8445
# medical                 7943
# moving                  5100
# vacation                4399
# house                   3560
# wedding                 2315
# renewable_energy         544
# educational              414
# Name: purpose, dtype: int64

# %%
pd.value_counts(df2nm['term'])
# Out:
#  36 months    584955
#  60 months    257595
# Name: term, dtype: int64

# %%
df2nm.groupby("loan_status")["funded_amnt"].mean()
# Out:
# loan_status
# Charged Off                                            14720.465557
# Current                                                15423.522779
# Default                                                15384.342334
# Does not meet the credit policy. Status:Charged Off     9322.687668
# Does not meet the credit policy. Status:Fully Paid      8717.493639
# Fully Paid                                             13404.535790
# In Grace Period                                        16152.647548
# Issued                                                 15552.701494
# Late (16-30 days)                                      15906.749436
# Late (31-120 days)                                     15852.402962
# Name: funded_amnt, dtype: float64

# %%
df2nm.groupby("loan_status")["emp_length2"].mean()
# Out:
# loan_status
# Charged Off                                            5.797486
# Current                                                6.100498
# Default                                                5.991289
# Does not meet the credit policy. Status:Charged Off    4.603217
# Does not meet the credit policy. Status:Fully Paid     4.044784
# Fully Paid                                             5.836422
# In Grace Period                                        5.895761
# Issued                                                 5.941755
# Late (16-30 days)                                      5.754402
# Late (31-120 days)                                     5.829286
# Name: emp_length2, dtype: float64

# %%
import numpy as np
df2nm['term2'] = np.where(df2nm['term']==' 36 months', 36, 60)
df2nm.head(10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0  1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1  1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2  1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3  1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 4  1075358     12.69   60 months     B        B5      Current     1 year
# 5  1075269      7.90   36 months     A        A4   Fully Paid    3 years
# 6  1069639     15.96   60 months     C        C5      Current    8 years
# ...

# %%
pd.value_counts(df2nm['term2'])
# Out:
# 36    584955
# 60    257595
# Name: term2, dtype: int64

# %%
def score_grade(x):
    if x == 'A':
        return 1
    if x=='B':
        return 2
    if x == 'C':
        return 3
    if x == 'D':
        return 4
    if x == 'E':
        return 5
    if x == 'F':
        return 6
    if x == 'G':
        return 7

# %%
df2nm['grade2'] = df2nm['grade'].apply(score_grade)
df2nm.head(20)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0   1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1   1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2   1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3   1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 4   1075358     12.69   60 months     B        B5      Current     1 year
# 5   1075269      7.90   36 months     A        A4   Fully Paid    3 years
# ...

# %%
pd.value_counts(df2nm['grade2'])
# Out:
# 2    241804
# 3    233184
# 1    141246
# 4    131774
# 5     67263
# 6     22004
# 7      5275
# Name: grade2, dtype: int64

# %%
df2nm.describe()
# Out:
#                  id       int_rate    funded_amnt    annual_inc  \
# count  8.425500e+05  842550.000000  842550.000000  8.425500e+05
# mean   3.229207e+07      13.245163   14899.890748  7.635332e+04
# std    2.283984e+07       4.385807    8444.846052  6.564285e+04
# min    5.473400e+04       5.320000     500.000000  1.896000e+03
# 25%    9.045242e+06       9.990000    8325.000000  4.700000e+04
# 50%    3.431207e+07      12.990000   13200.000000  6.500000e+04
# 75%    5.452376e+07      16.200000   20000.000000  9.000000e+04
# max    6.861706e+07      28.990000   35000.000000  9.500000e+06
#
#          emp_length2          term2         grade2
# count  842550.000000  842550.000000  842550.000000
# mean        6.008724      43.337582       2.797182
# std         3.666140      11.057215       1.314294
# min         0.000000      36.000000       1.000000
# 25%         3.000000      36.000000       2.000000
# 50%         6.000000      36.000000       3.000000
# ...

# %%
df2nm.corr()
# Out:
#                    id  int_rate  funded_amnt  annual_inc  emp_length2  \
# id           1.000000 -0.142854     0.070555    0.037740     0.012271
# int_rate    -0.142854  1.000000     0.149763   -0.072623     0.009285
# funded_amnt  0.070555  0.149763     1.000000    0.324730     0.106267
# annual_inc   0.037740 -0.072623     0.324730    1.000000     0.063998
# emp_length2  0.012271  0.009285     0.106267    0.063998     1.000000
# term2        0.072064  0.433089     0.407392    0.051599     0.068697
# grade2      -0.008402  0.954031     0.155385   -0.063889     0.004414
#
#                 term2    grade2
# id           0.072064 -0.008402
# int_rate     0.433089  0.954031
# funded_amnt  0.407392  0.155385
# annual_inc   0.051599 -0.063889
# emp_length2  0.068697  0.004414
# term2        1.000000  0.447876
# grade2       0.447876  1.000000

# %%
def score_lstatus(x):
    if x == 'Charged Off':
        return 0
    if x=='Fully Paid':
        return 1
    #if x == 'Default':
        #return 0

# %%
df2nm['loan_status2'] = df2nm['loan_status'].apply(score_lstatus)
df2nm.head(20)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0   1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1   1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2   1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3   1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 4   1075358     12.69   60 months     B        B5      Current     1 year
# 5   1075269      7.90   36 months     A        A4   Fully Paid    3 years
# ...

# %%
pd.value_counts(df2nm['loan_status2'])
# Out:
# 1.0    200351
# 0.0     42723
# Name: loan_status2, dtype: int64

# %%
df2nm.groupby("loan_status")["annual_inc"].mean()
# Out:
# loan_status
# Charged Off                                            66314.949848
# Current                                                77629.738879
# Default                                                68255.984477
# Does not meet the credit policy. Status:Charged Off    69978.537989
# Does not meet the credit policy. Status:Fully Paid     72428.589237
# Fully Paid                                             75068.707515
# In Grace Period                                        77076.359779
# Issued                                                 80555.274649
# Late (16-30 days)                                      74865.697585
# Late (31-120 days)                                     71586.609936
# Name: annual_inc, dtype: float64

# %%
df2nm.groupby("loan_status2")["annual_inc"].mean()
# Out:
# loan_status2
# 0.0    66314.949848
# 1.0    75068.707515
# Name: annual_inc, dtype: float64

# %%
#remove NaN after recoding loan_status
df3nm = df2nm.dropna()
df3nm.head()
# Out:
#         id  int_rate        term grade sub_grade  loan_status emp_length  \
# 0  1077501     10.65   36 months     B        B2   Fully Paid  10+ years
# 1  1077430     15.27   60 months     C        C4  Charged Off   < 1 year
# 2  1077175     15.96   36 months     C        C5   Fully Paid  10+ years
# 3  1076863     13.49   36 months     C        C1   Fully Paid  10+ years
# 5  1075269      7.90   36 months     A        A4   Fully Paid    3 years
#
#    funded_amnt         purpose  annual_inc  emp_length2  term2  grade2  \
# 0       5000.0     credit_card     24000.0           10     36       2
# 1       2500.0             car     30000.0            0     60       3
# 2       2400.0  small_business     12252.0           10     36       3
# 3      10000.0           other     49200.0           10     36       3
# 5       5000.0         wedding     36000.0            3     36       1
#
#    loan_status2
# 0           1.0
# 1           0.0
# 2           1.0
# 3           1.0
# ...

# %%
df3nm.describe()
# Out:
#                  id       int_rate    funded_amnt    annual_inc  \
# count  2.430740e+05  243074.000000  243074.000000  2.430740e+05
# mean   1.220285e+07      13.762363   13635.825304  7.353014e+04
# std    1.472869e+07       4.403093    8122.317689  5.947425e+04
# min    5.473400e+04       5.320000     500.000000  4.000000e+03
# 25%    1.452568e+06      10.740000    7500.000000  4.500000e+04
# 50%    6.285731e+06      13.530000   12000.000000  6.300000e+04
# 75%    1.640266e+07      16.550000   18400.000000  8.880000e+04
# max    6.860466e+07      28.990000   35000.000000  8.706582e+06
#
#          emp_length2          term2         grade2   loan_status2
# count  243074.000000  243074.000000  243074.000000  243074.000000
# mean        5.829579      41.423632       2.797959       0.824239
# std         3.621042      10.037520       1.338173       0.380618
# min         0.000000      36.000000       1.000000       0.000000
# ...

# %%
df3nm.corr()
# Out:
#                     id  int_rate  funded_amnt  annual_inc  emp_length2  \
# id            1.000000  0.041920     0.078103    0.041904     0.049673
# int_rate      0.041920  1.000000     0.217185   -0.025593     0.030770
# funded_amnt   0.078103  0.217185     1.000000    0.326849     0.117216
# annual_inc    0.041904 -0.025593     0.326849    1.000000     0.073911
# emp_length2   0.049673  0.030770     0.117216    0.073911     1.000000
# term2         0.096720  0.450780     0.396017    0.061891     0.071712
# grade2        0.124955  0.949592     0.212839   -0.016035     0.021561
# loan_status2  0.041250 -0.240382    -0.061665    0.056021     0.004093
#
#                  term2    grade2  loan_status2
# id            0.096720  0.124955      0.041250
# int_rate      0.450780  0.949592     -0.240382
# funded_amnt   0.396017  0.212839     -0.061665
# annual_inc    0.061891 -0.016035      0.056021
# emp_length2   0.071712  0.021561      0.004093
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ annual_inc + emp_length2 + term2 + grade2 + funded_amnt', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     3018.
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:06:39   Log-Likelihood:            -1.0279e+05
# No. Observations:              243074   AIC:                         2.056e+05
# Df Residuals:                  243068   BIC:                         2.056e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       1.0505      0.003    307.636      0.000       1.044       1.057
# ...

# %%
#remove intercept
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ annual_inc + emp_length2 + term2 + grade2 + funded_amnt - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.628e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:03:54   Log-Likelihood:            -1.4275e+05
# No. Observations:              243074   AIC:                         2.855e+05
# Df Residuals:                  243069   BIC:                         2.856e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# annual_inc   1.286e-06   1.54e-08     83.378      0.000    1.26e-06    1.32e-06
# ...

# %%
#remove term2
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ annual_inc + emp_length2 + grade2 + funded_amnt - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                 1.505e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:08:12   Log-Likelihood:            -1.6995e+05
# No. Observations:              243074   AIC:                         3.399e+05
# Df Residuals:                  243070   BIC:                         3.399e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# annual_inc   1.939e-06    1.7e-08    114.076      0.000    1.91e-06    1.97e-06
# ...

# %%
#added term back in, removed emp_length2
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ annual_inc + term2+ grade2 + funded_amnt - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                 1.966e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:12:02   Log-Likelihood:            -1.4599e+05
# No. Observations:              243074   AIC:                         2.920e+05
# Df Residuals:                  243070   BIC:                         2.920e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# annual_inc    1.42e-06   1.55e-08     91.332      0.000    1.39e-06    1.45e-06
# ...

# %%
#added term back in, removed emp_length2, annual_inc
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ term2+ grade2 + funded_amnt - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                 2.507e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:11:31   Log-Likelihood:            -1.5009e+05
# No. Observations:              243074   AIC:                         3.002e+05
# Df Residuals:                  243071   BIC:                         3.002e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# term2           0.0215    6.8e-05    316.723      0.000       0.021       0.022
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ term2 + grade2 - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                 3.760e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:03:56   Log-Likelihood:            -1.5011e+05
# No. Observations:              243074   AIC:                         3.002e+05
# Df Residuals:                  243072   BIC:                         3.002e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# term2          0.0217   5.61e-05    387.418      0.000       0.022       0.022
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='loan_status2 ~ term2 - 1', data=df3nm).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           loan_status2   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                 7.362e+05
# Date:                Fri, 03 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:03:57   Log-Likelihood:            -1.5206e+05
# No. Observations:              243074   AIC:                         3.041e+05
# Df Residuals:                  243073   BIC:                         3.041e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# term2          0.0185   2.15e-05    857.994      0.000       0.018       0.019
# ...

# %%
df3nm.to_csv('C:/Users/OWNER/Documents/DataBootcamp/loan/loandata.csv',index=False,header=True)
